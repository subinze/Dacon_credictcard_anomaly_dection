# %% [markdown]
# # Setup

# %% [markdown]
# ## 데이터 불러오기

# %%
import boto3
import pandas as pd
import botocore
from sagemaker import get_execution_role
import warnings
warnings.filterwarnings('ignore')

role = get_execution_role()

# s3 버킷 접근
bucket = 'sagemaker-studio-fu85vbeabbq'
s3_client = boto3.client('s3')
subfolder = 'data/'

# %%
# 학습 데이터 로드
train_key = 'data/train.csv'
response1 = s3_client.get_object(Bucket = bucket, Key = train_key)
train = pd.read_csv(response1['Body'])
train.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0   3 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1   4 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2   6 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3   8 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4   9 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 1  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 2  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 3 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 4  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
#
#         V26       V27       V28       V29       V30
# 0 -0.139097 -0.055353 -0.059752  4.983721 -0.994972
# 1 -0.221929  0.062723  0.061458  1.418291 -0.994972
# 2  0.105915  0.253844  0.081080 -0.256131 -0.994960
# 3 -0.051634 -1.206921 -1.085339  0.262698 -0.994901
# 4 -0.384157  0.011747  0.142404  0.994900 -0.994901
#
# [5 rows x 31 columns]

# %%
# 검증 데이터 로드
val_key = 'data/val.csv'
response2 = s3_client.get_object(Bucket = bucket, Key = val_key)
val = pd.read_csv(response2['Body'])
val.head()
# Out:
#    ID        V1        V2        V3        V4        V5        V6        V7  \
# 0  10 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
# 1  22  0.962496  0.328461 -0.171479  2.109204  1.129566  1.696038  0.107712
# 2  63  1.145524  0.575068  0.194008  2.598192 -0.092210 -1.044430  0.531588
# 3  69  0.927060 -0.323684  0.387585  0.544474  0.246787  1.650358 -0.427576
# 4  83 -3.005237  2.600138  1.483691 -2.418473  0.306326 -0.824575  2.065426
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.069539 -0.736727  ... -0.633753 -0.120794 -0.385050 -0.069733  0.094199
# 1  0.521502 -1.191311  ...  0.402492 -0.048508 -1.371866  0.390814  0.199964
# 2 -0.241888 -0.896287  ... -0.119703 -0.076510  0.691320  0.633984  0.048741
# 3  0.615371  0.226278  ...  0.079359  0.096632 -0.992569  0.085096  0.377447
# 4 -1.829347  4.009259  ... -0.181268 -0.163747  0.515821  0.136318  0.460054
#
#         V27       V28       V29       V30  Class
# 0  0.246219  0.083076 -0.255991 -0.994878      0
# 1  0.016371 -0.014605  0.168937 -0.994784      0
# 2 -0.053192  0.016251  0.169496 -0.994502      0
# 3  0.036096 -0.005960  0.331307 -0.994467      0
# 4 -0.251259 -1.105751 -0.287012 -0.994373      0
#
# [5 rows x 32 columns]

# %%
# 테스트 데이터 로드
test_key = 'data/test.csv'
response3 = s3_client.get_object(Bucket = bucket, Key = test_key)
test = pd.read_csv(response3['Body'])
test.head()
# Out:
#         ID        V1        V2        V3        V4        V5        V6  \
# 0  AAAA0x1 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1  AAAA0x2  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2  AAAA0x5 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 3  AAAA0x7  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 4  AAAA0xc  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
# 3 -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055
# 4  0.470455  0.538247 -0.558895  ...  0.049924  0.238422  0.009130  0.996710
#
#         V25       V26       V27       V28       V29       V30
# 0  0.128539 -0.189115  0.133558 -0.021053  1.783274 -0.994983
# 1  0.167170  0.125895 -0.008983  0.014724 -0.269825 -0.994983
# 2 -0.206010  0.502292  0.219422  0.215153  0.670579 -0.994960
# 3  0.750137 -0.257237  0.034507  0.005168 -0.237686 -0.994937
# 4 -0.767315 -0.492208  0.042472 -0.054337 -0.167819 -0.994866
#
# [5 rows x 31 columns]

# %% [markdown]
# ## 데이터 변형

# %% [markdown]
# ## Train 변형

# %%
train_df = train.drop('ID', axis = 1)
train_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 3 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 4 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 1  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 2  0.260314 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398 -0.371427
# 3 -3.807864  0.615375  1.249376  ...  1.943465 -1.015455  0.057504 -0.649709
# 4  0.851084 -0.392048 -0.410430  ... -0.073425 -0.268092 -0.204233  1.011592
#
#         V25       V26       V27       V28       V29       V30
# 0 -0.327642 -0.139097 -0.055353 -0.059752  4.983721 -0.994972
# 1  0.647376 -0.221929  0.062723  0.061458  1.418291 -0.994972
# 2 -0.232794  0.105915  0.253844  0.081080 -0.256131 -0.994960
# 3 -0.415267 -0.051634 -1.206921 -1.085339  0.262698 -0.994901
# 4  0.373205 -0.384157  0.011747  0.142404  0.994900 -0.994901
#
# [5 rows x 30 columns]

# %%
train_df.shape
# Out:
# (113842, 30)

# %%
# taxi_data와 유사, 한 열씩 연속적으로 들어가는 것 확인 가능!
# train_df.values.reshape(-1,1)
train_df.values
# Out:
# array([[ -1.35835406,  -1.34016307,   1.77320934, ...,  -0.05975184,
#           4.98372109,  -0.99497175],
#        [ -0.96627171,  -0.18522601,   1.79299334, ...,   0.06145763,
#           1.41829106,  -0.99497175],
#        [ -0.42596588,   0.96052304,   1.14110934, ...,   0.08108026,
#          -0.25613079,  -0.99496   ],
#        ...,
#        [ -0.24192292,   0.71224653,   0.39980566, ...,   0.08126506,
#          -0.23069936,   1.03490408],
#        [  0.12031638,   0.93100513,  -0.54601214, ...,   0.06880333,
#          -0.26982463,   1.03493932],
#        [-11.88111789,  10.07178497,  -9.83478346, ...,   0.82373096,
#          -0.29665339,   1.03495107]])

# %%
train_values = train_df.values

# %% [markdown]
# ## Val 변형

# %%
val_df_x = val.drop(['ID','Class'],axis = 1)
val_df_y = val[['Class']]

val_df_y.head()
# Out:
#    Class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
val_df_x.shape
# Out:
# (28462, 30)

# %%
val_df_x.values
# Out:
# array([[-0.33826175,  1.11959338,  1.04436655, ...,  0.08307565,
#         -0.25599106, -0.99487776],
#        [ 0.96249607,  0.32846103, -0.17147905, ..., -0.01460533,
#          0.16893733, -0.99478377],
#        [ 1.14552439,  0.57506797,  0.19400846, ...,  0.0162515 ,
#          0.16949626, -0.99450182],
#        ...,
#        [-0.4469509 ,  1.30221237, -0.16858299, ...,  0.22992129,
#          0.53797247,  1.0347631 ],
#        [ 2.03955977, -0.1752331 , -1.19682531, ..., -0.07507052,
#         -0.26996437,  1.03492757],
#        [-0.24044005,  0.53048251,  0.70251023, ...,  0.10453282,
#         -0.16767973,  1.03497457]])

# %%
val_values = val_df_x.values

# %% [markdown]
# ## Test 변형

# %%
test_df = test.drop(['ID'],axis = 1)
test_df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 3  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 4  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027  0.470455
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
# 3  0.081213  0.464960 -0.099254  ... -0.167716 -0.270710 -0.154104 -0.780055
# 4  0.538247 -0.558895  0.309755  ...  0.049924  0.238422  0.009130  0.996710
#
#         V25       V26       V27       V28       V29       V30
# 0  0.128539 -0.189115  0.133558 -0.021053  1.783274 -0.994983
# 1  0.167170  0.125895 -0.008983  0.014724 -0.269825 -0.994983
# 2 -0.206010  0.502292  0.219422  0.215153  0.670579 -0.994960
# 3  0.750137 -0.257237  0.034507  0.005168 -0.237686 -0.994937
# 4 -0.767315 -0.492208  0.042472 -0.054337 -0.167819 -0.994866
#
# [5 rows x 30 columns]

# %%
test_df.shape
# Out:
# (142503, 30)

# %%
test_values = test_df.values

# %%
test_values.shape
# Out:
# (142503, 30)

# %% [markdown]
# # Model

# %%
# model은 train set 이용해서 생성
# 사기비율 0.0039로 설정
# 트리 생성 개수 - 200
from sagemaker import RandomCutForest

session = sagemaker.Session()

# specify general training job information
rcf = RandomCutForest(
    role=role,
    instance_count=1,
    instance_type="ml.m4.xlarge",
    data_location=f"s3://{bucket}/{prefix}/",
    output_path=f"s3://{bucket}/{prefix}/output",
    num_samples_per_tree=512,
    num_trees=700, 
)

# automatically upload the training data to S3 and run the training job
rcf.fit(rcf.record_set(train_values))
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-08-04 17:25:37 Starting - Starting the training job...ProfilerReport-1659633936: InProgress
# ...
# 2022-08-04 17:26:29 Starting - Preparing the instances for training......
# 2022-08-04 17:27:31 Downloading - Downloading input data...
# 2022-08-04 17:27:52 Training - Downloading the training image.........
# 2022-08-04 17:29:30 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/04/2022 17:29:35 INFO 139767576684352] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-conf.json: {'num_samples_per_tree': 256, 'num_trees': 100, 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': 1000, '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999}
# [08/04/2022 17:29:35 INFO 139767576684352] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'mini_batch_size': '1000', 'num_samples_per_tree': '512', 'num_trees': '700'}
# [08/04/2022 17:29:35 INFO 139767576684352] Final configuration: {'num_samples_per_tree': '512', 'num_trees': '700', 'force_dense': 'true', 'eval_metrics': ['accuracy', 'precision_recall_fscore'], 'epochs': 1, 'mini_batch_size': '1000', '_log_level': 'info', '_kvstore': 'dist_async', '_num_kv_servers': 'auto', '_num_gpus': 'auto', '_tuning_objective_metric': '', '_ftp_port': 8999, 'feature_dim': '30'}
# [08/04/2022 17:29:35 WARNING 139767576684352] Loggers have already been setup.
# [08/04/2022 17:29:35 INFO 139767576684352] Launching parameter server for role scheduler
# [08/04/2022 17:29:35 INFO 139767576684352] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-175-236.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-08-04-17-25-36-663', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:966335049900:training-job/randomcutforest-2022-08-04-17-25-36-663', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-25311fafc59320a5c2af89b9ee728de22dcdfcb81f660c5b887406419eb040f0-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [08/04/2022 17:29:35 INFO 139767576684352] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-175-236.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-08-04-17-25-36-663', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:966335049900:training-job/randomcutforest-2022-08-04-17-25-36-663', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-25311fafc59320a5c2af89b9ee728de22dcdfcb81f660c5b887406419eb040f0-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.175.236', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [08/04/2022 17:29:35 INFO 139767576684352] Launching parameter server for role server
# [08/04/2022 17:29:35 INFO 139767576684352] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-175-236.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-08-04-17-25-36-663', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:966335049900:training-job/randomcutforest-2022-08-04-17-25-36-663', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-25311fafc59320a5c2af89b9ee728de22dcdfcb81f660c5b887406419eb040f0-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE'}
# [08/04/2022 17:29:35 INFO 139767576684352] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-175-236.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-08-04-17-25-36-663', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:966335049900:training-job/randomcutforest-2022-08-04-17-25-36-663', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-25311fafc59320a5c2af89b9ee728de22dcdfcb81f660c5b887406419eb040f0-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.175.236', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [08/04/2022 17:29:35 INFO 139767576684352] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-175-236.ap-northeast-2.compute.internal', 'TRAINING_JOB_NAME': 'randomcutforest-2022-08-04-17-25-36-663', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:ap-northeast-2:966335049900:training-job/randomcutforest-2022-08-04-17-25-36-663', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-25311fafc59320a5c2af89b9ee728de22dcdfcb81f660c5b887406419eb040f0-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'ap-northeast-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'KMP_DUPLICATE_LIB_OK': 'True', 'KMP_INIT_AT_FORK': 'FALSE', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.175.236', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 35 is a shell:scheduler.
# Process 47 is a shell:server.
# Process 1 is a worker.
# [08/04/2022 17:29:35 INFO 139767576684352] Using default worker.
# [08/04/2022 17:29:35 INFO 139767576684352] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [08/04/2022 17:29:35 INFO 139767576684352] Checkpoint loading and saving are disabled.
# [08/04/2022 17:29:35 INFO 139767576684352] Verifying hyperparamemters...
# [08/04/2022 17:29:35 INFO 139767576684352] Hyperparameters are correct.
# [08/04/2022 17:29:35 INFO 139767576684352] Validating that feature_dim agrees with dimensions in training data...
# [08/04/2022 17:29:35 INFO 139767576684352] feature_dim is correct.
# [08/04/2022 17:29:35 INFO 139767576684352] Validating memory limits...
# [08/04/2022 17:29:35 INFO 139767576684352] Available memory in bytes: 15210172416
# [08/04/2022 17:29:35 INFO 139767576684352] Estimated sample size in bytes: 172032000
# [08/04/2022 17:29:35 INFO 139767576684352] Estimated memory needed to build the forest in bytes: 430080000
# [08/04/2022 17:29:35 INFO 139767576684352] Memory limits validated.
# [08/04/2022 17:29:35 INFO 139767576684352] Starting cluster sharing facilities...
# [08/04/2022 17:29:35 INFO 139765659715328] concurrency model: async
# [08/04/2022 17:29:35 INFO 139765659715328] masquerade (NAT) address: None
# [08/04/2022 17:29:35 INFO 139765659715328] passive ports: None
# [08/04/2022 17:29:35 INFO 139765659715328] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [08/04/2022 17:29:35 INFO 139767576684352] Create Store: dist_async
# [08/04/2022 17:29:37 INFO 139767576684352] Cluster sharing facilities started.
# [08/04/2022 17:29:37 INFO 139767576684352] Verifying all workers are accessible...
# [08/04/2022 17:29:37 INFO 139767576684352] All workers accessible.
# [08/04/2022 17:29:37 INFO 139767576684352] Initializing Sampler...
# [08/04/2022 17:29:37 INFO 139767576684352] Sampler correctly initialized.
# #metrics {"StartTime": 1659634175.920249, "EndTime": 1659634177.6508021, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 1720.839262008667, "count": 1, "min": 1720.839262008667, "max": 1720.839262008667}}}
# #metrics {"StartTime": 1659634177.651005, "EndTime": 1659634177.651049, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-08-04 17:29:37.653] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 1732, "num_examples": 1, "num_bytes": 268000}
# [08/04/2022 17:29:37 INFO 139767576684352] Sampling training data...
# [2022-08-04 17:29:37.847] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 193, "num_examples": 114, "num_bytes": 30509656}
# [08/04/2022 17:29:37 INFO 139767576684352] Sampling training data completed.
# #metrics {"StartTime": 1659634177.6509464, "EndTime": 1659634177.8826385, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 229.19416427612305, "count": 1, "min": 229.19416427612305, "max": 229.19416427612305}}}
# [08/04/2022 17:29:37 INFO 139767576684352] Early stop condition met. Stopping training.
# [08/04/2022 17:29:37 INFO 139767576684352] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1659634177.6533997, "EndTime": 1659634177.883068, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 113842.0, "count": 1, "min": 113842, "max": 113842}, "Total Batches Seen": {"sum": 114.0, "count": 1, "min": 114, "max": 114}, "Max Records Seen Between Resets": {"sum": 113842.0, "count": 1, "min": 113842, "max": 113842}, "Max Batches Seen Between Resets": {"sum": 114.0, "count": 1, "min": 114, "max": 114}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 113842.0, "count": 1, "min": 113842, "max": 113842}, "Number of Batches Since Last Reset": {"sum": 114.0, "count": 1, "min": 114, "max": 114}}}
# [08/04/2022 17:29:37 INFO 139767576684352] #throughput_metric: host=algo-1, train throughput=495347.71793826413 records/second
# [08/04/2022 17:29:37 INFO 139767576684352] Master node: building Random Cut Forest...
# [08/04/2022 17:29:37 INFO 139767576684352] Gathering samples...
# [08/04/2022 17:29:37 INFO 139767576684352] 113842 samples gathered
# [08/04/2022 17:29:37 INFO 139767576684352] Building Random Cut Forest...
# [08/04/2022 17:29:38 INFO 139767576684352] Random Cut Forest built:
# ForestInfo{num_trees: 700, num_samples_in_forest: 113400, num_samples_per_tree: 162, sample_dim: 30, shingle_size: 1, trees_num_nodes: [323, 323, 321, 321, 321, 323, 321, 323, 319, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 319, 323, 323, 323, 323, 323, 323, 323, 319, 323, 323, 321, 319, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 321, 321, 319, 321, 321, 323, 323, 321, 323, 323, 321, 321, 323, 323, 323, 321, 323, 317, 323, 323, 323, 323, 323, 321, 321, 323, 323, 319, 323, 323, 323, 323, 323, 323, 323, 323, 323, 319, 323, 323, 321, 321, 323, 321, 323, 323, 319, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 321, 323, 323, 323, 323, 315, 321, 323, 321, 323, 323, 323, 323, 323, 319, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 319, 323, 323, 319, 323, 323, 323, 323, 323, 323, 321, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 317, 323, 323, 321, 321, 323, 323, 323, 323, 323, 321, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 321, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 315, 305, 317, 321, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 301, 317, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 313, 321, 323, 323, 323, 323, 319, 323, 323, 323, 323, 323, 321, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 319, 323, 323, 321, 323, 323, 319, 321, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 319, 321, 323, 321, 323, 323, 321, 323, 321, 321, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 321, 319, 323, 323, 323, 323, 323, 321, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 319, 323, 323, 321, 323, 323, 321, 323, 323, 323, 323, 319, 323, 323, 323, 321, 321, 323, 319, 323, 321, 323, 323, 321, 323, 321, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 319, 323, 323, 323, 323, 323, 323, 323, 315, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 321, 321, 323, 323, 323, 323, 323, 319, 323, 321, 323, 321, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 317, 323, 323, 323, 323, 323, 323, 323, 323, 317, 323, 323, 323, 323, 319, 323, 323, 313, 323, 323, 323, 323, 323, 323, 323, 321, 321, 323, 323, 323, 323, 321, 323, 321, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 317, 323, 323, 323, 323, 323, 323, 323, 317, 323, 323, 323, 323, 321, 319, 323, 323, 323, 323, 321, 323, 323, 323, 323, 317, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 323, 323, 321, 321, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 321, 323, 321, 323, 323, 321, 321, 323, 323, 323, 323, 323, 323, 317, 323, 323, 321, 323, 293, 319, 323, 321, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 321, 323, 323, 323, 323, 323, 319, 323, 323, 317, 323, 321, 323, ], trees_depth: [23, 20, 20, 20, 22, 23, 25, 33, 20, 25, 22, 24, 24, 22, 19, 26, 24, 33, 27, 28, 25, 24, 29, 28, 30, 29, 26, 22, 33, 17, 26, 25, 25, 23, 27, 22, 24, 21, 21, 29, 30, 23, 19, 28, 27, 18, 30, 28, 21, 21, 17, 22, 24, 29, 23, 19, 24, 24, 18, 28, 20, 25, 26, 25, 25, 19, 22, 25, 23, 23, 22, 26, 21, 23, 22, 22, 24, 25, 29, 26, 20, 22, 19, 28, 22, 23, 22, ...
# #metrics {"StartTime": 1659634177.8827462, "EndTime": 1659634178.3343585, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"fit_model.time": {"sum": 308.86268615722656, "count": 1, "min": 308.86268615722656, "max": 308.86268615722656}, "model.bytes": {"sum": 128155536.0, "count": 1, "min": 128155536, "max": 128155536}, "finalize.time": {"sum": 450.8626461029053, "count": 1, "min": 450.8626461029053, "max": 450.8626461029053}}}
# [08/04/2022 17:29:43 INFO 139767576684352] Master node: Serializing the RandomCutForest model
# #metrics {"StartTime": 1659634178.3345237, "EndTime": 1659634183.4834757, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"serialize_model.time": {"sum": 5148.875713348389, "count": 1, "min": 5148.875713348389, "max": 5148.875713348389}}}
# [08/04/2022 17:29:43 INFO 139767576684352] Test data is not provided.
# #metrics {"StartTime": 1659634183.4835799, "EndTime": 1659634183.4837344, "Dimensions": {"Algorithm": "RandomCutForest", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 37.068843841552734, "count": 1, "min": 37.068843841552734, "max": 37.068843841552734}, "totaltime": {"sum": 7613.0359172821045, "count": 1, "min": 7613.0359172821045, "max": 7613.0359172821045}}}
#
# 2022-08-04 17:29:50 Uploading - Uploading generated training model
# 2022-08-04 17:30:30 Completed - Training job completed
# Training seconds: 178
# Billable seconds: 178

# %%
# 알고리즘 이름 설명
# https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-train-model.html
print(f"Training job name: {rcf.latest_training_job.job_name}")
# Out:
# Training job name: randomcutforest-2022-08-04-17-25-36-663

# %% [markdown]
# # Inference

# %%
# https://docs.aws.amazon.com/sagemaker/latest/dg/deploy-model.html
# 또 다른 클러스터..?
rcf_inference = rcf.deploy(initial_instance_count=1, instance_type="ml.m4.xlarge")
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------!

# %%
print(f"Endpoint name: {rcf_inference.endpoint}")
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Endpoint name: randomcutforest-2022-08-04-17-30-49-891

# %% [markdown]
# # Data Serialization/Deserialization

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

rcf_inference.serializer = CSVSerializer()
rcf_inference.deserializer = JSONDeserializer()

# %%
# val로 predict 해서 검증
val_data_numpy = val_values
print(val_data_numpy[:][:2])  # [관계없이 다 나옴][2개씩 짤려서 나옴]
results = rcf_inference.predict(
    val_data_numpy[:][:2], initial_args={"ContentType": "text/csv", "Accept": "application/json"}
)
# Out:
# [[-0.33826175  1.11959338  1.04436655 -0.22218728  0.49936081 -0.2467611
#    0.65158321  0.06953859 -0.73672732 -0.36684564  1.01761447  0.83638957
#    1.00684351 -0.44352282  0.1502191   0.73945278 -0.54097992  0.47667726
#    0.45177296  0.20371145 -0.24691394 -0.63375264 -0.12079408 -0.38504993
#   -0.06973305  0.09419883  0.2462193   0.08307565 -0.25599106 -0.99487776]
#  [ 0.96249607  0.32846103 -0.17147905  2.10920407  1.12956557  1.69603769
#    0.10771161  0.52150216 -1.1913111   0.72439631  1.69032992  0.40677358
#   -0.9364213   0.98373942  0.71091077 -0.60223177  0.40248438 -1.73716203
#   -2.02761232 -0.26932097  0.14399742  0.40249166 -0.04850822 -1.37186629
#    0.39081389  0.19996366  0.01637064 -0.01460533  0.16893733 -0.99478377]]

# %%
# 하나의 행에 대한 값만 나옴!!!!!!야호
print(results)
# Out:
# {'scores': [{'score': 0.6612807645}, {'score': 0.9107015078}]}

# %%
val_df_x.shape
# Out:
# (28462, 30)

# %% [markdown]
# # Computing Anomaly Scores

# %% [markdown]
# ## val 이용한 예측

# %%
# 10000까지 predict 값을 내보냄!!!!!
result1 = rcf_inference.predict(val_data_numpy[:][:10000])
scores = [datum["score"] for datum in result1["scores"]]

# 새로운 데이터 프레임 생성
# add scores to taxi data frame and print first few valaues
val_score = pd.DataFrame({'score':scores}, index = [i+1 for i in range(10000)])
val_score.head()
# Out:
#       score
# 1  0.661281
# 2  0.910702
# 3  0.757459
# 4  0.834412
# 5  1.540064

# %%
# 300000 데이터 이상 부터 다시 predict
result2 = rcf_inference.predict(val_data_numpy[:][10000 : 20000])
scores2 = [datum["score"] for datum in result2["scores"]]

# 새로운 데이터 프레임 생성
# add scores to taxi data frame and print first few valaues
val_score2 = pd.DataFrame({'score':scores2}, index = [i+1 for i in range(10000, 20000)])
val_score2.head()
# Out:
#           score
# 10001  0.871877
# 10002  0.689525
# 10003  0.875250
# 10004  0.635300
# 10005  0.679694

# %%
# 60만 이상부터 predict
result3 = rcf_inference.predict(val_data_numpy[:][20000 :])
scores3 = [datum["score"] for datum in result3["scores"]]

# 새로운 데이터 프레임 생성
# add scores to taxi data frame and print first few valaues
val_score3 = pd.DataFrame({'score':scores3}, index = [i+1 for i in range(20000,28462)])
val_score3.head()
# Out:
#           score
# 20001  0.662260
# 20002  0.721373
# 20003  0.835770
# 20004  0.642915
# 20005  0.833826

# %% [markdown]
# ## val 전체 DataFrame 생성

# %%
val_pred_all = pd.concat([val_score, val_score2, val_score3], axis = 0)
print(val_pred_all.shape)
print(val_pred_all.head())
# Out:
# (28462, 1)
#       score
# 1  0.661281
# 2  0.910702
# 3  0.757459
# 4  0.834412
# 5  1.540064

# %%
val_pred_all.describe()
# Out:
#               score
# count  28462.000000
# mean       0.817123
# std        0.282911
# min        0.552363
# 25%        0.673005
# 50%        0.748221
# 75%        0.868090
# max        5.462714

# %% [markdown]
# ## 점수 표준화 하기!

# %% [markdown]
# ### 점수 매긴 값 표준화

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
val_pred_scaler = scaler.fit_transform(val_pred_all)
print(val_pred_scaler)
# Out:
# [[0.02218116]
#  [0.07297606]
#  [0.041768  ]
#  ...
#  [0.04344672]
#  [0.02368004]
#  [0.0673765 ]]

# %%
val_pred_scaler.shape
# Out:
# (28462, 1)

# %%
val_pred_scaler = pd.DataFrame(data = val_pred_scaler, columns = ['score'])
val_pred_scaler.head()
# Out:
#       score
# 0  0.022181
# 1  0.072976
# 2  0.041768
# 3  0.057440
# 4  0.201147

# %% [markdown]
# ## 그래프 그려보기!

# %%
val_pred_scaler.boxplot()
plt.show()

# %%
val_pred_scaler.describe()
# Out:
#               score
# count  28462.000000
# mean       0.053919
# std        0.057615
# min        0.000000
# 25%        0.024569
# 50%        0.039887
# 75%        0.064298
# max        1.000000

# %%
# 선택!!!!!!!!
val_pred_scaler[val_pred_scaler['score'] > 0.6].count()/28462
# Out:
# score    0.00123
# class    0.00123
# dtype: float64

# %%
val_pred_scaler[val_pred_scaler['score'] > 0.6].count()
# Out:
# score    35
# class    35
# dtype: int64

# %%
val_df_y['Class'].value_counts()
# Out:
# 0    28432
# 1       30
# Name: Class, dtype: int64

# %% [markdown]
# ## 구간 나눈 후 임계값 설정하기

# %% [markdown]
# ## 0.5를 기준으로

# %%
# 0~8까지 구간으로 나누기
# result 만들기
def result(score):
    if score < 0.6:
        answer = 0
    else:
        answer = 1
    return answer
        
val_pred_scaler['class'] = val_pred_scaler['score'].apply(lambda x: result(x)) 
val_pred_scaler.head(30)
# Out:
#        score  class
# 0   0.022181      0
# 1   0.072976      0
# 2   0.041768      0
# 3   0.057440      0
# 4   0.201147      0
# 5   0.024599      0
# 6   0.026245      0
# 7   0.051016      0
# 8   0.014679      0
# 9   0.035022      0
# 10  0.047608      0
# 11  0.212130      0
# 12  0.015096      0
# 13  0.021174      0
# 14  0.016993      0
# 15  0.020055      0
# 16  0.067006      0
# 17  0.039617      0
# 18  0.060465      0
# 19  0.036878      0
# 20  0.049823      0
# 21  0.034784      0
# 22  0.026382      0
# 23  0.044307      0
# 24  0.022132      0
# 25  0.130742      0
# 26  0.146174      0
# 27  0.034249      0
# 28  0.051477      0
# 29  0.052087      0

# %%
val_pred_scaler['class'].value_counts()
# Out:
# 0    28427
# 1       35
# Name: class, dtype: int64

# %% [markdown]
# ### 평가하기

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

val_score = f1_score(val_df_y, val_pred_scaler['class'], average='macro')
print(f'Validation F1 Score : [{val_score}]')
print(classification_report(val_df_y, val_pred_scaler['class']))
# Out:
# Validation F1 Score : [0.6688526408781778]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28432
#            1       0.31      0.37      0.34        30
#
#     accuracy                           1.00     28462
#    macro avg       0.66      0.68      0.67     28462
# weighted avg       1.00      1.00      1.00     28462

# %% [markdown]
# ### 0.45를 기준으로 - 당첨!

# %% [markdown]
# # Test 적용하기

# %%
test_values.shape
# Out:
# (142503, 30)

# %%
# 30만까지 predict 값을 내보냄!!!!!
# 15번 반복 
def predict(start,end):
    result = rcf_inference.predict(test_values[:][start:end])
    scores = [datum["score"] for datum in result["scores"]]

    # 새로운 데이터 프레임 생성
    # add scores to taxi data frame and print first few valaues
    val_score = pd.DataFrame({'score':scores}, index = [i+1 for i in range(start,end)])
    return val_score

# %%
# 전체 df 생성
start_end = [[0,10000],[10000,20000],[20000,30000],[30000,40000],[40000,50000], [50000, 60000],
            [60000, 70000],[70000,80000],[80000,90000],[90000,100000],[100000,110000],[110000,120000],[120000,130000],[130000,140000],[140000,142503]]

new_val = pd.concat([predict(nums[0],nums[1]) for nums in start_end], axis = 0) # start_end에 있는 값 넘겨주기

print(new_val.shape)
# Out:
# (142503, 1)

# %%
new_test = new_val

# %%
# 표준화 하기
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
new_test_scaler = scaler.fit_transform(new_test)
print(new_test_scaler)
# Out:
# [[0.02632544]
#  [0.00959019]
#  [0.01968982]
#  ...
#  [0.03910488]
#  [0.0411632 ]
#  [0.02275551]]

# %%
new_test_scaler = pd.DataFrame(data = new_test_scaler, columns = ['score'])
new_test_scaler.head()
# Out:
#       score
# 0  0.026325
# 1  0.009590
# 2  0.019690
# 3  0.015033
# 4  0.031426

# %%
new_test_scaler.shape
# Out:
# (142503, 1)

# %%
new_test_scaler.boxplot()
plt.show()

# %%
# best 값 찾기
new_test_scaler[new_test_scaler['score'] > 0.45].count()/142503
# Out:
# score    0.001684
# dtype: float64

# %%
# 0~8까지 구간으로 나누기
# result 만들기
def result(score):
    if score < 0.45:
        answer = 0
    else:
        answer = 1
    return answer
        
new_test_scaler['result'] = new_test_scaler['score'].apply(lambda x: result(x)) 
new_test_scaler.head(30)
# Out:
#        score  result
# 0   0.026325       0
# 1   0.009590       0
# 2   0.019690       0
# 3   0.015033       0
# 4   0.031426       0
# 5   0.031108       0
# 6   0.013264       0
# 7   0.036318       0
# 8   0.029158       0
# 9   0.043743       0
# 10  0.014155       0
# 11  0.018652       0
# 12  0.004901       0
# 13  0.012217       0
# 14  0.014352       0
# 15  0.014785       0
# 16  0.014785       0
# 17  0.037977       0
# 18  0.010965       0
# 19  0.036644       0
# 20  0.016280       0
# 21  0.041807       0
# 22  0.015896       0
# 23  0.033775       0
# 24  0.017026       0
# 25  0.008492       0
# 26  0.019405       0
# 27  0.032475       0
# 28  0.010186       0
# 29  0.014872       0

# %% [markdown]
# ## 수정하기!!!

# %%
new_test_scaler['result'].value_counts()
# Out:
# 0    142263
# 1       240
# Name: result, dtype: int64

# %% [markdown]
# # submission 정리

# %%
# submission 데이터 로드
submit_key = 'data/sample_submission.csv'
response4 = s3_client.get_object(Bucket = bucket, Key = submit_key)
submit = pd.read_csv(response4['Body'])
submit.head()
# Out:
#         ID  Class
# 0  AAAA0x1      1
# 1  AAAA0x2      1
# 2  AAAA0x5      1
# 3  AAAA0x7      1
# 4  AAAA0xc      1

# %%
submit['Class'] = new_test_scaler['result']

submit.head()
# Out:
#         ID  Class
# 0  AAAA0x1      0
# 1  AAAA0x2      0
# 2  AAAA0x5      0
# 3  AAAA0x7      0
# 4  AAAA0xc      0

# %%
submit['Class'].value_counts()
# Out:
# 0    142263
# 1       240
# Name: Class, dtype: int64

# %%
import s3fs

s3 = s3fs.S3FileSystem(anon=False)

# Use 'w' for py3, 'wb' for py2
with s3.open('sagemaker-studio-fu85vbeabbq/submission_rcf_3.csv','w') as f:
    submit.to_csv(f,index = False)

# %%
sagemaker.Session().delete_endpoint(rcf_inference.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
